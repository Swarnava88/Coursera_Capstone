# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Week 1-2)
#
# # Business Problem section
#
# ## Background
#
# ### According to Bloomberg News, the London Housing Market is in a rut. It is now facing a number of different headwinds, including the prospect of higher taxes and a warning from the Bank of England that U.K. home values could fall as much as 30 percent in the event of a disorderly exit from the European Union. More specifically, four overlooked cracks suggest that the London market may be in worse shape than many realize: hidden price falls, record-low sales, homebuilder exodus and tax hikes addressing overseas buyers of homes in England and Wales.
#
# ## Business Problem
# In this scenario, it is urgent to adopt machine learning tools in order to assist homebuyers clientele in London to make wise and effective decisions. As a result, the business problem we are currently posing is: how could we provide support to homebuyers clientele in to purchase a suitable real estate in London in this uncertain economic and financial scenario?
#
# To solve this business problem, we are going to cluster London neighborhoods in order to recommend venues and the current average price of real estate where homebuyers can make a real estate investment. We will recommend profitable venues according to amenities and essential facilities surrounding such venues i.e. elementary schools, high schools, hospitals & grocery stores.
#
# ## Data section
# Data on London properties and the relative price paid data were extracted from the HM Land Registry (http://landregistry.data.gov.uk/). The following fields comprise the address data included in Price Paid Data: Postcode; PAON Primary Addressable Object Name. Typically the house number or name; SAON Secondary Addressable Object Name. If there is a sub-building, for example, the building is divided into flats, there will be a SAON; Street; Locality; Town/City; District; County.
#
# To explore and target recommended locations across different venues according to the presence of amenities and essential facilities, we will access data through FourSquare API interface and arrange them as a dataframe for visualization. By merging data on London properties and the relative price paid data from the HM Land Registry and data on amenities and essential facilities surrounding such properties from FourSquare API interface, we will be able to recommend profitable real estate investments.
#
#  ## Methodology section
# The Methodology section will describe the main components of our analysis and predication system. The Methodology section comprises four stages:
#
# 1. Collect Inspection Data
# 2. Explore and Understand Data
# 3. Data preparation and preprocessing
# 4. Modeling

# %%
import os # Operating System
import numpy as np
import pandas as pd
import datetime as dt # Datetime
import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# !conda install -c conda-forge folium=0.5.0 --yes
import folium #import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
#Read the data for examination (Source: http://landregistry.data.gov.uk/)
df_ppd = pd.read_csv("http://prod2.publicdata.landregistry.gov.uk.s3-website-eu-west-1.amazonaws.com/pp-2018.csv")

# %%
df_ppd.head(100)
# Out:
#     {7011B109-CFCA-8ED6-E053-6B04A8C075C1}  280000  2018-06-04 00:00  \
# 0   {7011B109-CFCB-8ED6-E053-6B04A8C075C1}  280000  2018-05-29 00:00
# 1   {7011B109-CFCC-8ED6-E053-6B04A8C075C1}  170000  2018-04-27 00:00
# 2   {7011B109-CFCD-8ED6-E053-6B04A8C075C1}  246000  2018-05-25 00:00
# 3   {7011B109-CFCE-8ED6-E053-6B04A8C075C1}  180000  2018-06-08 00:00
# 4   {7011B109-CFCF-8ED6-E053-6B04A8C075C1}  245000  2018-05-11 00:00
# 5   {7011B109-CFD0-8ED6-E053-6B04A8C075C1}  269000  2018-05-15 00:00
# 6   {7011B109-CFD1-8ED6-E053-6B04A8C075C1}  270000  2018-03-20 00:00
# 7   {7011B109-CFD2-8ED6-E053-6B04A8C075C1}  350000  2018-04-17 00:00
# 8   IP12 1LB  T  N  F                         33        NaN
# 9    IP4 5JL  T  N  F                         98        NaN
# 10   IP3 9BT  S  N  F                        305        NaN
# 11  IP33 3HG  T  N  F                          1        NaN
# 12   IP3 0QA  S  N  F                         13        NaN
# 13   IP4 4LQ  D  N  F                        103        NaN
# 14  IP12 4UU  T  N  F                          7        NaN
# 15  CO10 0XX  D  N  F                          6        NaN
# 16   IP4 5AJ  T  N  F                        291        NaN
# 17   IP1 6JG  S  N  F                         72        NaN
# 18   CB9 9AU  T  N  F                          8        NaN
# 19  IP11 0YR  T  N  F                         53        NaN
# 20  CO10 7UF  T  N  F                          3        NaN
# 21  CO10 7UF  F  N  L                         30        NaN
# 22  IP28 7QA  T  N  F                         15        NaN
# 23   IP1 2LD  T  N  F                         42        NaN
# 24   IP1 3PD  T  N  F                         54        NaN
# 25   IP1 3PA  S  N  F                         45        NaN
# 26   IP4 1PL  T  N  F                         44        NaN
# 27   CB8 7SD  D  N  F                         16        NaN
# 28   CB9 0LW  T  N  F                         19        NaN
# 29   IP2 0LA  S  N  F                         46        NaN
# 30   IP1 6AE  S  N  F                        152        NaN
# 31  IP14 2PG  T  N  F                         18        NaN
# 32  IP13 9BX  T  N  F                         12        NaN
# 33   SY3 9FT  D  Y  F                         26        NaN
# 34  TF12 5LQ  D  Y  F                         64        NaN
# 35   SY8 3RE  D  Y  F                         12        NaN
# 36  SY13 4NU  D  N  F                GABLES FARM        NaN
# 37  TF11 9BA  D  N  F                         9B        NaN
# 38  SY13 1FG  D  Y  F                         12        NaN
# 39  TF10 8HX  D  N  F          VIEWLANDS COTTAGE        NaN
# 40  SY13 1FG  D  Y  F                          1        NaN
# 41   TF9 3FS  D  Y  F                          8        NaN
# 42   SY3 0LS  D  Y  F                         10        NaN
# 43  SY13 1FG  D  Y  F                          7        NaN
# 44   SY2 6FN  T  Y  F                        149        NaN
# 45   SY2 6FL  D  Y  F                         70        NaN
# 46   TF1 2FJ  D  Y  F                          1        NaN
# 47   SY2 6FL  D  Y  F                         72        NaN
# 48   SY2 6FN  T  Y  F                        141        NaN
# 49   SY2 6FN  T  Y  F                        151        NaN
# 50   SY1 2BN  D  Y  F                         64        NaN
# 51  SY13 1FG  D  Y  F                         14        NaN
# 52   SY3 0LS  D  Y  F                          8        NaN
# 53  TF11 8GL  D  Y  F                          7        NaN
# 54   SY4 1EB  D  N  F          WINGFIELD COTTAGE        NaN
# 55   SY3 5FU  F  Y  L                         49        NaN
# 56   SY3 5FU  F  Y  L                         35        NaN
# 57   SY3 5FU  F  Y  L                         47        NaN
# 58  SY12 0FJ  T  Y  F                         96        NaN
# 59  SY13 1EA  T  N  F                          1        NaN
# 60   SY1 2BN  D  Y  F                         66        NaN
# 61  DY14 8DA  D  N  F                          1        NaN
# 62  TA24 6GW  F  N  L              MARLING HOUSE    FLAT 24
# 63   TA4 1QW  T  N  F                        102        NaN
# 64  BS21 7SB  F  N  L                         18     FLAT 1
# 65   TA1 3BD  T  N  F                         18        NaN
# 66  TA21 9DQ  T  N  F                          2        NaN
# 67   TA1 3TF  F  N  L                         54        NaN
# 68  BA20 2NL  S  N  F                          1        NaN
# 69  BS24 9UT  D  N  F                         25        NaN
# 70   TA8 2BT  F  N  L            ALLANDALE COURT         11
# 71  BS49 4LL  S  N  F                         20        NaN
# 72   BA2 2DR  S  N  F                         12        NaN
# 73  BS23 2BU  F  N  L                         42    FLAT 20
# 74  BS31 2PX  S  N  F                          5        NaN
# 75  BS24 7HA  S  N  F                        131        NaN
# 76  BS23 3XN  S  N  F                          1        NaN
# 77  BS39 5PS  S  N  F                         17        NaN
# 78  BS20 7BS  D  N  F                         11        NaN
# 79  TA24 5QF  F  N  L                    CARTREF     FLAT 1
# 80  BS39 7RQ  D  N  F          WINTERFIELD HOUSE        NaN
# 81  BS24 7EG  D  N  F                         44        NaN
# 82  TA12 6DR  S  N  F                         47        NaN
# 83  BS23 1DH  F  N  L        EDDINGTON COURT, 30     FLAT 4
# 84  TA23 0QT  D  N  F                          5        NaN
# 85   TA4 1AZ  D  N  F                 LUSHINGTON        NaN
# 86  BA11 2TD  D  N  F                          9        NaN
# 87   TA6 4EU  T  N  F                         45        NaN
# 88  BS25 5LX  T  N  F                          6        NaN
# 89  BS23 3WG  F  N  L                         48        NaN
# 90  BS31 2BD  F  N  L                          5        NaN
# 91  BS24 7EG  S  N  F                        112        NaN
# 92   TA1 1EE  T  N  F                          6        NaN
# 93  TA19 0LE  D  N  F                 HONEYMOUNT        NaN
# 94  BA11 1PB  T  N  F                         10        NaN
# 95  TA11 6LH  S  N  F                          5        NaN
# 96   TA8 2RF  F  N  L  CHESTNUT HOUSE KNOLL PARK    FLAT 3D
# 97  BA21 5AN  F  N  L                         1B        NaN
# 98  BA16 0SP  S  N  F                          6        NaN
# 99  BA22 9BT  T  N  F                         20        NaN
#
#           RANDWELL CLOSE         Unnamed: 10            IPSWICH  \
# 0           NORWICH ROAD                 NaN            IPSWICH
# 1            PARADE ROAD                 NaN            IPSWICH
# 2          ELMCROFT ROAD                 NaN            IPSWICH
# 3        WYNTERTON CLOSE                 NaN            IPSWICH
# 4           NORWICH ROAD                 NaN            IPSWICH
# 5             ROY AVENUE                 NaN            IPSWICH
# 6    KINGFISHER CRESCENT              REYDON          SOUTHWOLD
# 7            MANOR CLOSE           CAVENDISH            SUDBURY
# 8         FERNHILL CLOSE                 NaN         WOODBRIDGE
# 9          FREEHOLD ROAD                 NaN            IPSWICH
# 10       FELIXSTOWE ROAD                 NaN            IPSWICH
# 11           GREENE ROAD                 NaN    BURY ST EDMUNDS
# 12        DEREHAM AVENUE                 NaN            IPSWICH
# 13         RUSHMERE ROAD                 NaN            IPSWICH
# 14       CHURCHILL CLOSE                 NaN         WOODBRIDGE
# 15        HOLBROOK CLOSE  GREAT WALDINGFIELD            SUDBURY
# 16   CAULDWELL HALL ROAD                 NaN            IPSWICH
# 17            BYRON ROAD                 NaN            IPSWICH
# 18          QUEENS COURT                 NaN          HAVERHILL
# 19      THE WHEELWRIGHTS     TRIMLEY ST MARY         FELIXSTOWE
# 20            GOWERS END           GLEMSFORD            SUDBURY
# 21            GOWERS END           GLEMSFORD            SUDBURY
# 22          SELWYN CLOSE          MILDENHALL    BURY ST EDMUNDS
# 23           SIRDAR ROAD                 NaN            IPSWICH
# 24            ANN STREET                 NaN            IPSWICH
# 25     CUMBERLAND STREET                 NaN            IPSWICH
# 26        WELLESLEY ROAD                 NaN            IPSWICH
# 27           WRAGG DRIVE                 NaN          NEWMARKET
# 28          PIPERS CLOSE                 NaN          HAVERHILL
# 29         LAVENHAM ROAD                 NaN            IPSWICH
# 30         ASHCROFT ROAD                 NaN            IPSWICH
# 31        FLATFORD CLOSE                 NaN         STOWMARKET
# 32         PAGEANT PLACE         FRAMLINGHAM         WOODBRIDGE
# 33          MERCERS LANE                 NaN         SHREWSBURY
# 34           HAYCOP RISE                 NaN           BROSELEY
# 35      HIGHNAM CRESCENT           CLEE HILL             LUDLOW
# 36                   NaN           IGHTFIELD         WHITCHURCH
# 37           PARK STREET                 NaN            SHIFNAL
# 38             THE CROFT                 NaN         WHITCHURCH
# 39       SHREWSBURY ROAD             EDGMOND            NEWPORT
# 40             THE CROFT                 NaN         WHITCHURCH
# 41         BLANDFORD WAY                 NaN     MARKET DRAYTON
# 42          JARVIS DRIVE        BAYSTON HILL         SHREWSBURY
# 43             THE CROFT                 NaN         WHITCHURCH
# 44           MURRELL WAY                 NaN         SHREWSBURY
# 45           MURRELL WAY                 NaN         SHREWSBURY
# 46      WISEMAN CRESCENT          WELLINGTON            TELFORD
# 47           MURRELL WAY                 NaN         SHREWSBURY
# 48           MURRELL WAY                 NaN         SHREWSBURY
# 49           MURRELL WAY                 NaN         SHREWSBURY
# 50          JUNIPER ROAD                 NaN         SHREWSBURY
# 51             THE CROFT                 NaN         WHITCHURCH
# 52          JARVIS DRIVE        BAYSTON HILL         SHREWSBURY
# 53          BRAMBLE LANE                 NaN            SHIFNAL
# 54                   NaN     MONTFORD BRIDGE         SHREWSBURY
# 55          THE FURLONGS        BICTON HEATH         SHREWSBURY
# 56          THE FURLONGS        BICTON HEATH         SHREWSBURY
# 57          THE FURLONGS        BICTON HEATH         SHREWSBURY
# 58   TETCHILL BROOK ROAD                 NaN          ELLESMERE
# 59             DODINGTON                 NaN         WHITCHURCH
# 60          JUNIPER ROAD                 NaN         SHREWSBURY
# 61           CASTLE HILL   CLEOBURY MORTIMER      KIDDERMINSTER
# 62           TRINITY WAY                 NaN           MINEHEAD
# 63          BURGE MEADOW     COTFORD ST LUKE            TAUNTON
# 64         VICTORIA ROAD                 NaN           CLEVEDON
# 65          NOBLE STREET                 NaN            TAUNTON
# 66            POPES LANE      ROCKWELL GREEN         WELLINGTON
# 67      ST JOSEPHS FIELD                 NaN            TAUNTON
# 68        CHESTNUT DRIVE                 NaN             YEOVIL
# 69         CANADA COOMBE              HUTTON  WESTON-SUPER-MARE
# 70          RECTORY ROAD                 NaN     BURNHAM-ON-SEA
# 71           STREAMCROSS           CLAVERHAM            BRISTOL
# 72          HENSLEY ROAD                 NaN               BATH
# 73         BIRNBECK ROAD                 NaN  WESTON-SUPER-MARE
# 74         LULWORTH ROAD            KEYNSHAM            BRISTOL
# 75         LONGRIDGE WAY                 NaN  WESTON-SUPER-MARE
# 76           STUART ROAD                 NaN  WESTON-SUPER-MARE
# 77         CAPPARDS ROAD       BISHOP SUTTON            BRISTOL
# 78              WOODACRE          PORTISHEAD            BRISTOL
# 79        WEIRFIELD ROAD                 NaN           MINEHEAD
# 80      WINTERFIELD ROAD             PAULTON            BRISTOL
# 81       WORLE MOOR ROAD                 NaN  WESTON-SUPER-MARE
# 82            BIRCH ROAD                 NaN            MARTOCK
# 83            BEACH ROAD                 NaN  WESTON-SUPER-MARE
# 84      WATERSMEET CLOSE           ROADWATER            WATCHET
# 85                   NaN                OAKE            TAUNTON
# 86          PENNYS PIECE                 NaN              FROME
# 87        ROSEVEAN CLOSE                 NaN         BRIDGWATER
# 88  THE OLD SCHOOL CLOSE           CHURCHILL          WINSCOMBE
# 89      MACFARLANE CHASE                 NaN  WESTON-SUPER-MARE
# 90     TRESCOTHICK CLOSE            KEYNSHAM            BRISTOL
# 91       WORLE MOOR ROAD                 NaN  WESTON-SUPER-MARE
# 92           BIRCH GROVE                 NaN            TAUNTON
# 93         MIDDLE STREET   SHEPTON BEAUCHAMP          ILMINSTER
# 94         NEW BUILDINGS                 NaN              FROME
# 95        LABURNUM DRIVE                 NaN           SOMERTON
# 96            SOUTH ROAD               BREAN     BURNHAM-ON-SEA
# 97         CROMWELL ROAD                 NaN             YEOVIL
# 98          SEYMOUR ROAD                 NaN             STREET
# 99            LAKEFIELDS          WEST COKER             YEOVIL
#
#                        IPSWICH.1                       SUFFOLK  A A.1
# 0                        IPSWICH                       SUFFOLK  A   A
# 1                        IPSWICH                       SUFFOLK  A   A
# 2                        IPSWICH                       SUFFOLK  A   A
# 3                        IPSWICH                       SUFFOLK  A   A
# 4                        IPSWICH                       SUFFOLK  A   A
# 5                        IPSWICH                       SUFFOLK  A   A
# 6                        WAVENEY                       SUFFOLK  A   A
# 7                 ST EDMUNDSBURY                       SUFFOLK  A   A
# 8                SUFFOLK COASTAL                       SUFFOLK  A   A
# 9                        IPSWICH                       SUFFOLK  A   A
# 10                       IPSWICH                       SUFFOLK  A   A
# 11                ST EDMUNDSBURY                       SUFFOLK  A   A
# 12                       IPSWICH                       SUFFOLK  A   A
# 13                       IPSWICH                       SUFFOLK  A   A
# 14               SUFFOLK COASTAL                       SUFFOLK  A   A
# 15                       BABERGH                       SUFFOLK  A   A
# 16                       IPSWICH                       SUFFOLK  A   A
# 17                       IPSWICH                       SUFFOLK  A   A
# 18                ST EDMUNDSBURY                       SUFFOLK  A   A
# 19               SUFFOLK COASTAL                       SUFFOLK  A   A
# 20                       BABERGH                       SUFFOLK  A   A
# 21                       BABERGH                       SUFFOLK  A   A
# 74  BATH AND NORTH EAST SOMERSET  BATH AND NORTH EAST SOMERSET  A   A
# 75                NORTH SOMERSET                NORTH SOMERSET  A   A
# 76                NORTH SOMERSET                NORTH SOMERSET  A   A
# 77  BATH AND NORTH EAST SOMERSET  BATH AND NORTH EAST SOMERSET  A   A
# 78                NORTH SOMERSET                NORTH SOMERSET  A   A
# 79                 WEST SOMERSET                      SOMERSET  A   A
# 80  BATH AND NORTH EAST SOMERSET  BATH AND NORTH EAST SOMERSET  A   A
# 81                NORTH SOMERSET                NORTH SOMERSET  A   A
# 82                SOUTH SOMERSET                      SOMERSET  A   A
# 83                NORTH SOMERSET                NORTH SOMERSET  A   A
# 84                 WEST SOMERSET                      SOMERSET  A   A
# 85                 TAUNTON DEANE                      SOMERSET  A   A
# 86                        MENDIP                      SOMERSET  A   A
# 87                     SEDGEMOOR                      SOMERSET  A   A
# 88                NORTH SOMERSET                NORTH SOMERSET  A   A
# 89                NORTH SOMERSET                NORTH SOMERSET  A   A
# 90  BATH AND NORTH EAST SOMERSET  BATH AND NORTH EAST SOMERSET  A   A
# 91                NORTH SOMERSET                NORTH SOMERSET  A   A
# 92                 TAUNTON DEANE                      SOMERSET  A   A
# 93                SOUTH SOMERSET                      SOMERSET  A   A
# 94                        MENDIP                      SOMERSET  A   A
# 95                SOUTH SOMERSET                      SOMERSET  A   A
# 96                     SEDGEMOOR                      SOMERSET  B   A
# 97                SOUTH SOMERSET                      SOMERSET  A   A
# 98                        MENDIP                      SOMERSET  A   A
# 99                SOUTH SOMERSET                      SOMERSET  A   A

# %%
df_ppd.shape
# Out:
# (1026571, 16)

# %%
# Assign meaningful column names
df_ppd.columns = ['TUID', 'Price', 'Date_Transfer', 'Postcode', 'Prop_Type', 'Old_New', 'Duration', 'PAON', \
                  'SAON', 'Street', 'Locality', 'Town_City', 'District', 'County', 'PPD_Cat_Type', 'Record_Status']

# %%
# Format the date column
df_ppd['Date_Transfer'] = df_ppd['Date_Transfer'].apply(pd.to_datetime)

# Delete all obsolete transactions which were done before 2016
df_ppd.drop(df_ppd[df_ppd.Date_Transfer.dt.year < 2016].index, inplace=True)

# Sort by Date of Sale
df_ppd.sort_values(by=['Date_Transfer'],ascending=[False],inplace=True)

# %%
df_ppd_london = df_ppd.query("Town_City == 'LONDON'")

# Make a list of street names in LONDON
streets = df_ppd_london['Street'].unique().tolist()

# %%
df_grp_price = df_ppd_london.groupby(['Street'])['Price'].mean().reset_index()

# Give meaningful names to the columns
df_grp_price.columns = ['Street', 'Avg_Price']

# %%
#Input your Budget's Upper Limit and Lower Limit - Find the locations df_grp_price which fits your budget
df_affordable = df_grp_price.query("(Avg_Price >= 2200000) & (Avg_Price <= 2500000)")

# %%
# Display the dataframe
df_affordable
# Out:
#                           Street     Avg_Price
# 196                ALBION SQUARE  2.450000e+06
# 391                  ANHALT ROAD  2.435000e+06
# 406              ANSDELL TERRACE  2.250000e+06
# 422              APPLEGARTH ROAD  2.400000e+06
# 6603              HORTENSIA ROAD  2.275917e+06
# 6632               HOXTON SQUARE  2.234286e+06
# 6658                 HUNTER ROAD  2.300000e+06
# 6817               JACKSONS LANE  2.362500e+06
# 6877                 JOHN STREET  2.235000e+06
# 7181            KINNERTON STREET  2.485600e+06
# 7215         KNARESBOROUGH PLACE  2.325000e+06
# 7235                 KNOX STREET  2.250000e+06
# 7255              LADBROKE GROVE  2.483300e+06
# 7324              LANCASTER MEWS  2.312500e+06
# 7394              LANSDOWNE ROAD  2.429871e+06
# 7422   LATIMER INDUSTRIAL ESTATE  2.400000e+06
# 7475                LAXTON PLACE  2.500000e+06
# 7677              LINCOLN AVENUE  2.203500e+06
# 7705              LINGFIELD ROAD  2.248750e+06
# 7734               LISSON STREET  2.462500e+06
# 7768             LIVERPOOL GROVE  2.288000e+06
# 7860              LONGWOOD DRIVE  2.375000e+06
# 7866             LONSDALE SQUARE  2.357500e+06
# 8404                   MAZE HILL  2.250000e+06
# 8539           MIDDLESEX PASSAGE  2.280000e+06
# 8702           MONTPELIER AVENUE  2.500000e+06
# 8712             MONTPELIER WALK  2.320000e+06
# 8860                 MULTON ROAD  2.300000e+06
# 8865               MUNDEN STREET  2.250000e+06
# 9139            NORFOLK CRESCENT  2.223333e+06
# 9162         NORTH CIRCULAR ROAD  2.393143e+06
# 9238           NOTTINGHAM STREET  2.227500e+06
# 9313               OAKLEY STREET  2.381286e+06
# 9324               OAKWOOD COURT  2.348750e+06
# 9332         OBSERVATORY GARDENS  2.420000e+06
# 9367             OLD COURT PLACE  2.395000e+06
# 9428            ONSLOW MEWS WEST  2.300000e+06
# 9560                PALACE PLACE  2.300000e+06
# 9589               PANTON STREET  2.475000e+06
# 9608               PARK CRESCENT  2.440000e+06
# 9617                   PARK LANE  2.241500e+06
# 9638                  PARKE ROAD  2.262500e+06
# 9641                  PARKFIELDS  2.200000e+06
# 9678              PARTHENIA ROAD  2.200567e+06
# 9710               PAVILION ROAD  2.200000e+06
# 9771              PEMBRIDGE MEWS  2.251000e+06
# 9773              PEMBRIDGE ROAD  2.400000e+06
# 9782            PEMBROKE STUDIOS  2.450000e+06
# 9787               PENCOMBE MEWS  2.200000e+06
# 9866             PETERSHAM PLACE  2.300000e+06
# 9881          PHILLIMORE GARDENS  2.484667e+06
# 9889                PHYSIC PLACE  2.500000e+06
# 9927             PITFIELD STREET  2.483333e+06
# 10137               PRINCES GATE  2.403333e+06
# 10165                PRIORY ROAD  2.248258e+06
# 10176           PROTHERO GARDENS  2.202500e+06
# 10212         PUTNEY HIGH STREET  2.348600e+06
# 10229          QUARRENDON STREET  2.437750e+06
# 10262        QUEENS GATE TERRACE  2.399444e+06
# 10316            RADSTOCK STREET  2.217500e+06
# 10361            RANELAGH AVENUE  2.300000e+06
# 10468             REDCLIFFE ROAD  2.448750e+06
# 10493                REEVES MEWS  2.450000e+06
# 10550               RHEIDOL MEWS  2.310000e+06
# 10605            RINGWOOD AVENUE  2.275000e+06
# 10685              RODERICK ROAD  2.400000e+06
# 10742          ROPEMAKERS FIELDS  2.500000e+06
# 10856             ROYAL CRESCENT  2.348333e+06
# 10862                 ROYAL HILL  2.252500e+06
# 10919       RUSSELL GARDENS MEWS  2.300000e+06
# 11166             SETTLES STREET  2.487500e+06
# 11241             SHELDON AVENUE  2.349542e+06
# 11475              SOUTH END ROW  2.470000e+06
# 11553        SOUTHWOOD LAWN ROAD  2.350000e+06
# 11556             SOVEREIGN PARK  2.500000e+06
# 11773      ST MARGARETS CRESCENT  2.216500e+06
# 11809           ST OSWALDS PLACE  2.250000e+06
# 11829           ST PETERS SQUARE  2.468730e+06
# 11866           STAFFORD TERRACE  2.355000e+06
# 12205           SUTHERLAND PLACE  2.456000e+06
# 12267              SYDNEY STREET  2.240833e+06
# 12409                THAMES BANK  2.400000e+06
# 12471                THE HEXAGON  2.335000e+06
# 12750            TREDEGAR SQUARE  2.436666e+06
# 12812             TRINITY STREET  2.317500e+06
# 12962       UPPER HAMPSTEAD WALK  2.500000e+06
# 13224            WALPOLE GARDENS  2.303500e+06
# 13226             WALPOLE STREET  2.242500e+06
# 13300             WARWICK SQUARE  2.432273e+06
# 13398                WELBECK WAY  2.267000e+06
# 13410          WELLESLEY TERRACE  2.410000e+06
# 13421          WELLINGTON STREET  2.293155e+06
# 13553         WESTMORELAND PLACE  2.300000e+06
# 13660           WHITFIELD STREET  2.451000e+06
# 13705             WILFRED STREET  2.410538e+06
# 13731         WILLOW BRIDGE ROAD  2.425000e+06
# 13751              WILSON STREET  2.257500e+06
# 13779            WINCHENDON ROAD  2.350000e+06
# 13816               WINGATE ROAD  2.206400e+06

# %%
import pandas as pd
import numpy as np
import datetime as DT
import hmac
from geopy.geocoders import Nominatim
from geopy.distance import vincenty
# import k-means from clustering stage
from sklearn.cluster import KMeans

# %%
for index, item in df_affordable.iterrows():
    print(f"index: {index}")
    print(f"item: {item}")
    print(f"item.Street only: {item.Street}")
# Out:
# index: 196
# item: Street       ALBION SQUARE
# Avg_Price         2.45e+06
# Name: 196, dtype: object
# item.Street only: ALBION SQUARE
# index: 391
# item: Street       ANHALT ROAD
# Avg_Price      2.435e+06
# Name: 391, dtype: object
# item.Street only: ANHALT ROAD
# index: 406
# item: Street       ANSDELL TERRACE
# Avg_Price           2.25e+06
# Name: 406, dtype: object
# item.Street only: ANSDELL TERRACE
# index: 422
# item: Street       APPLEGARTH ROAD
# Avg_Price            2.4e+06
# Name: 422, dtype: object
# item.Street only: APPLEGARTH ROAD
# index: 855
# item: Street       BARONSMEAD ROAD
# Avg_Price          2.375e+06
# Name: 855, dtype: object
# item.Street only: BARONSMEAD ROAD
# index: 981
# item: Street       BEAUCLERC ROAD
# Avg_Price          2.48e+06
# Name: 981, dtype: object
# item.Street only: BEAUCLERC ROAD
# index: 1102
# item: Street       BELVEDERE DRIVE
# Avg_Price           2.34e+06
# Name: 1102, dtype: object
# item.Street only: BELVEDERE DRIVE
# index: 1215
# item: Street       BICKENHALL STREET
# Avg_Price           2.2085e+06
# Name: 1215, dtype: object
# item.Street only: BICKENHALL STREET
# index: 1253
# item: Street       BIRCHLANDS AVENUE
# Avg_Price            2.217e+06
# Name: 1253, dtype: object
# item.Street only: BIRCHLANDS AVENUE
# index: 1553
# item: Street       BRAMPTON GROVE
# Avg_Price       2.45688e+06
# Name: 1553, dtype: object
# item.Street only: BRAMPTON GROVE
# index: 1632
# item: Street       BRIARDALE GARDENS
# Avg_Price          2.39713e+06
# Name: 1632, dtype: object
# item.Street only: BRIARDALE GARDENS
# index: 1797
# item: Street       BROOKWAY
# Avg_Price     2.4e+06
# Name: 1797, dtype: object
# item.Street only: BROOKWAY
# index: 1914
# item: Street       BURBAGE ROAD
# Avg_Price       2.445e+06
# Name: 1914, dtype: object
# item.Street only: BURBAGE ROAD
# index: 1980
# item: Street        BURY WALK
# Avg_Price    2.4925e+06
# Name: 1980, dtype: object
# item.Street only: BURY WALK
# index: 2068
# item: Street       CALLCOTT STREET
# Avg_Price          2.375e+06
# Name: 2068, dtype: object
# item.Street only: CALLCOTT STREET
# index: 2129
# item: Street       CAMPDEN HILL ROAD
# Avg_Price          2.37965e+06
# Name: 2129, dtype: object
# item.Street only: CAMPDEN HILL ROAD
# index: 2136
# item: Street       CAMPION ROAD
# Avg_Price       2.461e+06
# Name: 2136, dtype: object
# item.Street only: CAMPION ROAD
# index: 2158
# item: Street       CANNING PLACE
# Avg_Price        2.425e+06
# Name: 2158, dtype: object
# item.Street only: CANNING PLACE
# index: 2225
# item: Street       CARLISLE ROAD
# Avg_Price          2.2e+06
# Name: 2225, dtype: object
# item.Street only: CARLISLE ROAD
# index: 2230
# item: Street       CARLTON GARDENS
# Avg_Price         2.4835e+06
# Name: 2230, dtype: object
# item.Street only: CARLTON GARDENS
# index: 2242
# item: Street       CARLYLE COURT
# Avg_Price          2.3e+06
# Name: 2242, dtype: object
# item.Street only: CARLYLE COURT
# index: 2405
# item: Street       CHALCOT SQUARE
# Avg_Price       2.28668e+06
# Name: 2405, dtype: object
# item.Street only: CHALCOT SQUARE
# index: 2483
# item: Street       CHARLES LANE
# Avg_Price       2.414e+06
# Name: 2483, dtype: object
# item.Street only: CHARLES LANE
# index: 2561
# item: Street       CHELSEA CRESCENT
# Avg_Price           2.495e+06
# Name: 2561, dtype: object
# item.Street only: CHELSEA CRESCENT
# index: 2605
# item: Street       CHESTER CLOSE NORTH
# Avg_Price               2.45e+06
# Name: 2605, dtype: object
# item.Street only: CHESTER CLOSE NORTH
# index: 2637
# item: Street       CHEYNE COURT
# Avg_Price        2.25e+06
# Name: 2637, dtype: object
# item.Street only: CHEYNE COURT
# index: 2640
# item: Street       CHEYNE ROW
# Avg_Price      2.41e+06
# Name: 2640, dtype: object
# item.Street only: CHEYNE ROW
# index: 2685
# item: Street       CHISWICK MALL
# Avg_Price       2.2875e+06
# Name: 2685, dtype: object
# item.Street only: CHISWICK MALL
# index: 2760
# item: Street         CITY ROAD
# Avg_Price    2.46834e+06
# Name: 2760, dtype: object
# item.Street only: CITY ROAD
# index: 2807
# item: Street       CLARENDON STREET
# Avg_Price            2.25e+06
# Name: 2807, dtype: object
# item.Street only: CLARENDON STREET
# index: 2899
# item: Street       CLONCURRY STREET
# Avg_Price         2.38833e+06
# Name: 2899, dtype: object
# item.Street only: CLONCURRY STREET
# index: 2943
# item: Street       COLBECK MEWS
# Avg_Price      2.3675e+06
# Name: 2943, dtype: object
# item.Street only: COLBECK MEWS
# index: 2994
# item: Street       COLLEGE CRESCENT
# Avg_Price            2.44e+06
# Name: 2994, dtype: object
# item.Street only: COLLEGE CRESCENT
# index: 3201
# item: Street       CORNWALL TERRACE MEWS
# Avg_Price                 2.35e+06
# Name: 3201, dtype: object
# item.Street only: CORNWALL TERRACE MEWS
# index: 3254
# item: Street       COURT LANE GARDENS
# Avg_Price              2.36e+06
# Name: 3254, dtype: object
# item.Street only: COURT LANE GARDENS
# index: 3376
# item: Street       CRESCENT GROVE
# Avg_Price         2.298e+06
# Name: 3376, dtype: object
# item.Street only: CRESCENT GROVE
# index: 3582
# item: Street       DALEBURY ROAD
# Avg_Price          2.4e+06
# Name: 3582, dtype: object
# item.Street only: DALEBURY ROAD
# index: 3847
# item: Street       DEWHURST ROAD
# Avg_Price        2.425e+06
# Name: 3847, dtype: object
# item.Street only: DEWHURST ROAD
# index: 3928
# item: Street       DORIA ROAD
# Avg_Price    2.3625e+06
# Name: 3928, dtype: object
# item.Street only: DORIA ROAD
# index: 3979
# item: Street       DOWNSHIRE HILL
# Avg_Price         2.225e+06
# Name: 3979, dtype: object
# item.Street only: DOWNSHIRE HILL
# index: 4034
# item: Street       DUCHESS WALK
# Avg_Price      2.4775e+06
# Name: 4034, dtype: object
# item.Street only: DUCHESS WALK
# index: 4231
# item: Street       ECCLESTON SQUARE MEWS
# Avg_Price               2.3355e+06
# Name: 4231, dtype: object
# item.Street only: ECCLESTON SQUARE MEWS
# index: 4284
# item: Street       EGBERT STREET
# Avg_Price        2.265e+06
# Name: 4284, dtype: object
# item.Street only: EGBERT STREET
# index: 4288
# item: Street       EGERTON PLACE
# Avg_Price          2.2e+06
# Name: 4288, dtype: object
# item.Street only: EGERTON PLACE
# index: 4373
# item: Street       ELM PARK ROAD
# Avg_Price      2.32042e+06
# Name: 4373, dtype: object
# item.Street only: ELM PARK ROAD
# index: 5011
# item: Street       FRANK DIXON WAY
# Avg_Price         2.2125e+06
# Name: 5011, dtype: object
# item.Street only: FRANK DIXON WAY
# index: 5093
# item: Street       FULTON MEWS
# Avg_Price      2.299e+06
# Name: 5093, dtype: object
# item.Street only: FULTON MEWS
# index: 5236
# item: Street       GERARD ROAD
# Avg_Price     2.2585e+06
# Name: 5236, dtype: object
# item.Street only: GERARD ROAD
# index: 5239
# item: Street       GERRARD ROAD
# Avg_Price      2.2425e+06
# Name: 5239, dtype: object
# item.Street only: GERRARD ROAD
# index: 5284
# item: Street       GIRDLERS ROAD
# Avg_Price      2.44167e+06
# Name: 5284, dtype: object
# item.Street only: GIRDLERS ROAD
# index: 5377
# item: Street       GLOUCESTER CRESCENT
# Avg_Price            2.35083e+06
# Name: 5377, dtype: object
# item.Street only: GLOUCESTER CRESCENT
# index: 5445
# item: Street       GORDON PLACE
# Avg_Price       2.477e+06
# Name: 5445, dtype: object
# item.Street only: GORDON PLACE
# index: 5481
# item: Street       GRAFTON SQUARE
# Avg_Price          2.27e+06
# Name: 5481, dtype: object
# item.Street only: GRAFTON SQUARE
# index: 5488
# item: Street       GRAHAM TERRACE
# Avg_Price         2.325e+06
# Name: 5488, dtype: object
# item.Street only: GRAHAM TERRACE
# index: 5946
# item: Street       HARMAN DRIVE
# Avg_Price      2.2625e+06
# Name: 5946, dtype: object
# item.Street only: HARMAN DRIVE
# index: 5970
# item: Street       HARRIS STREET
# Avg_Price      2.47177e+06
# Name: 5970, dtype: object
# item.Street only: HARRIS STREET
# index: 6032
# item: Street       HAVANNAH STREET
# Avg_Price        2.21731e+06
# Name: 6032, dtype: object
# item.Street only: HAVANNAH STREET
# index: 6104
# item: Street       HAZLEWELL ROAD
# Avg_Price           2.5e+06
# Name: 6104, dtype: object
# item.Street only: HAZLEWELL ROAD
# index: 6220
# item: Street       HEREFORD MEWS
# Avg_Price         2.31e+06
# Name: 6220, dtype: object
# item.Street only: HEREFORD MEWS
# index: 6240
# item: Street       HERONDALE AVENUE
# Avg_Price           2.475e+06
# Name: 6240, dtype: object
# item.Street only: HERONDALE AVENUE
# index: 6337
# item: Street       HIGHGATE HIGH STREET
# Avg_Price               2.211e+06
# Name: 6337, dtype: object
# item.Street only: HIGHGATE HIGH STREET
# index: 6352
# item: Street       HIGHWOOD HILL
# Avg_Price       2.2525e+06
# Name: 6352, dtype: object
# item.Street only: HIGHWOOD HILL
# index: 6388
# item: Street       HILLGATE PLACE
# Avg_Price           2.2e+06
# Name: 6388, dtype: object
# item.Street only: HILLGATE PLACE
# index: 6499
# item: Street       HOLLYCROFT AVENUE
# Avg_Price          2.36138e+06
# Name: 6499, dtype: object
# item.Street only: HOLLYCROFT AVENUE
# index: 6503
# item: Street       HOLLYWOOD MEWS
# Avg_Price          2.35e+06
# Name: 6503, dtype: object
# item.Street only: HOLLYWOOD MEWS
# index: 6548
# item: Street       HONEYWELL ROAD
# Avg_Price       2.27833e+06
# Name: 6548, dtype: object
# item.Street only: HONEYWELL ROAD
# index: 6603
# item: Street       HORTENSIA ROAD
# Avg_Price       2.27592e+06
# Name: 6603, dtype: object
# item.Street only: HORTENSIA ROAD
# index: 6632
# item: Street       HOXTON SQUARE
# Avg_Price      2.23429e+06
# Name: 6632, dtype: object
# item.Street only: HOXTON SQUARE
# index: 6658
# item: Street       HUNTER ROAD
# Avg_Price        2.3e+06
# Name: 6658, dtype: object
# item.Street only: HUNTER ROAD
# index: 6817
# item: Street       JACKSONS LANE
# Avg_Price       2.3625e+06
# Name: 6817, dtype: object
# item.Street only: JACKSONS LANE
# index: 6877
# item: Street       JOHN STREET
# Avg_Price      2.235e+06
# Name: 6877, dtype: object
# item.Street only: JOHN STREET
# index: 7181
# item: Street       KINNERTON STREET
# Avg_Price          2.4856e+06
# Name: 7181, dtype: object
# item.Street only: KINNERTON STREET
# index: 7215
# item: Street       KNARESBOROUGH PLACE
# Avg_Price              2.325e+06
# Name: 7215, dtype: object
# item.Street only: KNARESBOROUGH PLACE
# index: 7235
# item: Street       KNOX STREET
# Avg_Price       2.25e+06
# Name: 7235, dtype: object
# item.Street only: KNOX STREET
# index: 7255
# item: Street       LADBROKE GROVE
# Avg_Price        2.4833e+06
# Name: 7255, dtype: object
# item.Street only: LADBROKE GROVE
# index: 7324
# item: Street       LANCASTER MEWS
# Avg_Price        2.3125e+06
# Name: 7324, dtype: object
# item.Street only: LANCASTER MEWS
# index: 7394
# item: Street       LANSDOWNE ROAD
# Avg_Price       2.42987e+06
# Name: 7394, dtype: object
# item.Street only: LANSDOWNE ROAD
# index: 7422
# item: Street       LATIMER INDUSTRIAL ESTATE
# Avg_Price                      2.4e+06
# Name: 7422, dtype: object
# item.Street only: LATIMER INDUSTRIAL ESTATE
# index: 7475
# item: Street       LAXTON PLACE
# Avg_Price         2.5e+06
# Name: 7475, dtype: object
# item.Street only: LAXTON PLACE
# index: 7677
# item: Street       LINCOLN AVENUE
# Avg_Price        2.2035e+06
# Name: 7677, dtype: object
# item.Street only: LINCOLN AVENUE
# index: 7705
# item: Street       LINGFIELD ROAD
# Avg_Price       2.24875e+06
# Name: 7705, dtype: object
# item.Street only: LINGFIELD ROAD
# index: 7734
# item: Street       LISSON STREET
# Avg_Price       2.4625e+06
# Name: 7734, dtype: object
# item.Street only: LISSON STREET
# index: 7768
# item: Street       LIVERPOOL GROVE
# Avg_Price          2.288e+06
# Name: 7768, dtype: object
# item.Street only: LIVERPOOL GROVE
# index: 7860
# item: Street       LONGWOOD DRIVE
# Avg_Price         2.375e+06
# Name: 7860, dtype: object
# item.Street only: LONGWOOD DRIVE
# index: 7866
# item: Street       LONSDALE SQUARE
# Avg_Price         2.3575e+06
# Name: 7866, dtype: object
# item.Street only: LONSDALE SQUARE
# index: 8404
# item: Street       MAZE HILL
# Avg_Price     2.25e+06
# Name: 8404, dtype: object
# item.Street only: MAZE HILL
# index: 8539
# item: Street       MIDDLESEX PASSAGE
# Avg_Price             2.28e+06
# Name: 8539, dtype: object
# item.Street only: MIDDLESEX PASSAGE
# index: 8702
# item: Street       MONTPELIER AVENUE
# Avg_Price              2.5e+06
# Name: 8702, dtype: object
# item.Street only: MONTPELIER AVENUE
# index: 8712
# item: Street       MONTPELIER WALK
# Avg_Price           2.32e+06
# Name: 8712, dtype: object
# item.Street only: MONTPELIER WALK
# index: 8860
# item: Street       MULTON ROAD
# Avg_Price        2.3e+06
# Name: 8860, dtype: object
# item.Street only: MULTON ROAD
# index: 8865
# item: Street       MUNDEN STREET
# Avg_Price         2.25e+06
# Name: 8865, dtype: object
# item.Street only: MUNDEN STREET
# index: 9139
# item: Street       NORFOLK CRESCENT
# Avg_Price         2.22333e+06
# Name: 9139, dtype: object
# item.Street only: NORFOLK CRESCENT
# index: 9162
# item: Street       NORTH CIRCULAR ROAD
# Avg_Price            2.39314e+06
# Name: 9162, dtype: object
# item.Street only: NORTH CIRCULAR ROAD
# index: 9238
# item: Street       NOTTINGHAM STREET
# Avg_Price           2.2275e+06
# Name: 9238, dtype: object
# item.Street only: NOTTINGHAM STREET
# index: 9313
# item: Street       OAKLEY STREET
# Avg_Price      2.38129e+06
# Name: 9313, dtype: object
# item.Street only: OAKLEY STREET
# index: 9324
# item: Street       OAKWOOD COURT
# Avg_Price      2.34875e+06
# Name: 9324, dtype: object
# item.Street only: OAKWOOD COURT
# index: 9332
# item: Street       OBSERVATORY GARDENS
# Avg_Price               2.42e+06
# Name: 9332, dtype: object
# item.Street only: OBSERVATORY GARDENS
# index: 9367
# item: Street       OLD COURT PLACE
# Avg_Price          2.395e+06
# Name: 9367, dtype: object
# item.Street only: OLD COURT PLACE
# index: 9428
# item: Street       ONSLOW MEWS WEST
# Avg_Price             2.3e+06
# Name: 9428, dtype: object
# item.Street only: ONSLOW MEWS WEST
# index: 9560
# item: Street       PALACE PLACE
# Avg_Price         2.3e+06
# Name: 9560, dtype: object
# item.Street only: PALACE PLACE
# index: 9589
# item: Street       PANTON STREET
# Avg_Price        2.475e+06
# Name: 9589, dtype: object
# item.Street only: PANTON STREET
# index: 9608
# item: Street       PARK CRESCENT
# Avg_Price         2.44e+06
# Name: 9608, dtype: object
# item.Street only: PARK CRESCENT
# index: 9617
# item: Street        PARK LANE
# Avg_Price    2.2415e+06
# Name: 9617, dtype: object
# item.Street only: PARK LANE
# index: 9638
# item: Street       PARKE ROAD
# Avg_Price    2.2625e+06
# Name: 9638, dtype: object
# item.Street only: PARKE ROAD
# index: 9641
# item: Street       PARKFIELDS
# Avg_Price       2.2e+06
# Name: 9641, dtype: object
# item.Street only: PARKFIELDS
# index: 9678
# item: Street       PARTHENIA ROAD
# Avg_Price       2.20057e+06
# Name: 9678, dtype: object
# item.Street only: PARTHENIA ROAD
# index: 9710
# item: Street       PAVILION ROAD
# Avg_Price          2.2e+06
# Name: 9710, dtype: object
# item.Street only: PAVILION ROAD
# index: 9771
# item: Street       PEMBRIDGE MEWS
# Avg_Price         2.251e+06
# Name: 9771, dtype: object
# item.Street only: PEMBRIDGE MEWS
# index: 9773
# item: Street       PEMBRIDGE ROAD
# Avg_Price           2.4e+06
# Name: 9773, dtype: object
# item.Street only: PEMBRIDGE ROAD
# index: 9782
# item: Street       PEMBROKE STUDIOS
# Avg_Price            2.45e+06
# Name: 9782, dtype: object
# item.Street only: PEMBROKE STUDIOS
# index: 9787
# item: Street       PENCOMBE MEWS
# Avg_Price          2.2e+06
# Name: 9787, dtype: object
# item.Street only: PENCOMBE MEWS
# index: 9866
# item: Street       PETERSHAM PLACE
# Avg_Price            2.3e+06
# Name: 9866, dtype: object
# item.Street only: PETERSHAM PLACE
# index: 9881
# item: Street       PHILLIMORE GARDENS
# Avg_Price           2.48467e+06
# Name: 9881, dtype: object
# item.Street only: PHILLIMORE GARDENS
# index: 9889
# item: Street       PHYSIC PLACE
# Avg_Price         2.5e+06
# Name: 9889, dtype: object
# item.Street only: PHYSIC PLACE
# index: 9927
# item: Street       PITFIELD STREET
# Avg_Price        2.48333e+06
# Name: 9927, dtype: object
# item.Street only: PITFIELD STREET
# index: 10137
# item: Street       PRINCES GATE
# Avg_Price     2.40333e+06
# Name: 10137, dtype: object
# item.Street only: PRINCES GATE
# index: 10165
# item: Street       PRIORY ROAD
# Avg_Price    2.24826e+06
# Name: 10165, dtype: object
# item.Street only: PRIORY ROAD
# index: 10176
# item: Street       PROTHERO GARDENS
# Avg_Price          2.2025e+06
# Name: 10176, dtype: object
# item.Street only: PROTHERO GARDENS
# index: 10212
# item: Street       PUTNEY HIGH STREET
# Avg_Price            2.3486e+06
# Name: 10212, dtype: object
# item.Street only: PUTNEY HIGH STREET
# index: 10229
# item: Street       QUARRENDON STREET
# Avg_Price          2.43775e+06
# Name: 10229, dtype: object
# item.Street only: QUARRENDON STREET
# index: 10262
# item: Street       QUEENS GATE TERRACE
# Avg_Price            2.39944e+06
# Name: 10262, dtype: object
# item.Street only: QUEENS GATE TERRACE
# index: 10316
# item: Street       RADSTOCK STREET
# Avg_Price         2.2175e+06
# Name: 10316, dtype: object
# item.Street only: RADSTOCK STREET
# index: 10361
# item: Street       RANELAGH AVENUE
# Avg_Price            2.3e+06
# Name: 10361, dtype: object
# item.Street only: RANELAGH AVENUE
# index: 10468
# item: Street       REDCLIFFE ROAD
# Avg_Price       2.44875e+06
# Name: 10468, dtype: object
# item.Street only: REDCLIFFE ROAD
# index: 10493
# item: Street       REEVES MEWS
# Avg_Price       2.45e+06
# Name: 10493, dtype: object
# item.Street only: REEVES MEWS
# index: 10550
# item: Street       RHEIDOL MEWS
# Avg_Price        2.31e+06
# Name: 10550, dtype: object
# item.Street only: RHEIDOL MEWS
# index: 10605
# item: Street       RINGWOOD AVENUE
# Avg_Price          2.275e+06
# Name: 10605, dtype: object
# item.Street only: RINGWOOD AVENUE
# index: 10685
# item: Street       RODERICK ROAD
# Avg_Price          2.4e+06
# Name: 10685, dtype: object
# item.Street only: RODERICK ROAD
# index: 10742
# item: Street       ROPEMAKERS FIELDS
# Avg_Price              2.5e+06
# Name: 10742, dtype: object
# item.Street only: ROPEMAKERS FIELDS
# index: 10856
# item: Street       ROYAL CRESCENT
# Avg_Price       2.34833e+06
# Name: 10856, dtype: object
# item.Street only: ROYAL CRESCENT
# index: 10862
# item: Street       ROYAL HILL
# Avg_Price    2.2525e+06
# Name: 10862, dtype: object
# item.Street only: ROYAL HILL
# index: 10919
# item: Street       RUSSELL GARDENS MEWS
# Avg_Price                 2.3e+06
# Name: 10919, dtype: object
# item.Street only: RUSSELL GARDENS MEWS
# index: 11166
# item: Street       SETTLES STREET
# Avg_Price        2.4875e+06
# Name: 11166, dtype: object
# item.Street only: SETTLES STREET
# index: 11241
# item: Street       SHELDON AVENUE
# Avg_Price       2.34954e+06
# Name: 11241, dtype: object
# item.Street only: SHELDON AVENUE
# index: 11475
# item: Street       SOUTH END ROW
# Avg_Price         2.47e+06
# Name: 11475, dtype: object
# item.Street only: SOUTH END ROW
# index: 11553
# item: Street       SOUTHWOOD LAWN ROAD
# Avg_Price               2.35e+06
# Name: 11553, dtype: object
# item.Street only: SOUTHWOOD LAWN ROAD
# index: 11556
# item: Street       SOVEREIGN PARK
# Avg_Price           2.5e+06
# Name: 11556, dtype: object
# item.Street only: SOVEREIGN PARK
# index: 11773
# item: Street       ST MARGARETS CRESCENT
# Avg_Price               2.2165e+06
# Name: 11773, dtype: object
# item.Street only: ST MARGARETS CRESCENT
# index: 11809
# item: Street       ST OSWALDS PLACE
# Avg_Price            2.25e+06
# Name: 11809, dtype: object
# item.Street only: ST OSWALDS PLACE
# index: 11829
# item: Street       ST PETERS SQUARE
# Avg_Price         2.46873e+06
# Name: 11829, dtype: object
# item.Street only: ST PETERS SQUARE
# index: 11866
# item: Street       STAFFORD TERRACE
# Avg_Price           2.355e+06
# Name: 11866, dtype: object
# item.Street only: STAFFORD TERRACE
# index: 12205
# item: Street       SUTHERLAND PLACE
# Avg_Price           2.456e+06
# Name: 12205, dtype: object
# item.Street only: SUTHERLAND PLACE
# index: 12267
# item: Street       SYDNEY STREET
# Avg_Price      2.24083e+06
# Name: 12267, dtype: object
# item.Street only: SYDNEY STREET
# index: 12409
# item: Street       THAMES BANK
# Avg_Price        2.4e+06
# Name: 12409, dtype: object
# item.Street only: THAMES BANK
# index: 12471
# item: Street       THE HEXAGON
# Avg_Price      2.335e+06
# Name: 12471, dtype: object
# item.Street only: THE HEXAGON
# index: 12750
# item: Street       TREDEGAR SQUARE
# Avg_Price        2.43667e+06
# Name: 12750, dtype: object
# item.Street only: TREDEGAR SQUARE
# index: 12812
# item: Street       TRINITY STREET
# Avg_Price        2.3175e+06
# Name: 12812, dtype: object
# item.Street only: TRINITY STREET
# index: 12962
# item: Street       UPPER HAMPSTEAD WALK
# Avg_Price                 2.5e+06
# Name: 12962, dtype: object
# item.Street only: UPPER HAMPSTEAD WALK
# index: 13224
# item: Street       WALPOLE GARDENS
# Avg_Price         2.3035e+06
# Name: 13224, dtype: object
# item.Street only: WALPOLE GARDENS
# index: 13226
# item: Street       WALPOLE STREET
# Avg_Price        2.2425e+06
# Name: 13226, dtype: object
# item.Street only: WALPOLE STREET
# index: 13300
# item: Street       WARWICK SQUARE
# Avg_Price       2.43227e+06
# Name: 13300, dtype: object
# item.Street only: WARWICK SQUARE
# index: 13398
# item: Street       WELBECK WAY
# Avg_Price      2.267e+06
# Name: 13398, dtype: object
# item.Street only: WELBECK WAY
# index: 13410
# item: Street       WELLESLEY TERRACE
# Avg_Price             2.41e+06
# Name: 13410, dtype: object
# item.Street only: WELLESLEY TERRACE
# index: 13421
# item: Street       WELLINGTON STREET
# Avg_Price          2.29316e+06
# Name: 13421, dtype: object
# item.Street only: WELLINGTON STREET
# index: 13553
# item: Street       WESTMORELAND PLACE
# Avg_Price               2.3e+06
# Name: 13553, dtype: object
# item.Street only: WESTMORELAND PLACE
# index: 13660
# item: Street       WHITFIELD STREET
# Avg_Price           2.451e+06
# Name: 13660, dtype: object
# item.Street only: WHITFIELD STREET
# index: 13705
# item: Street       WILFRED STREET
# Avg_Price       2.41054e+06
# Name: 13705, dtype: object
# item.Street only: WILFRED STREET
# index: 13731
# item: Street       WILLOW BRIDGE ROAD
# Avg_Price             2.425e+06
# Name: 13731, dtype: object
# item.Street only: WILLOW BRIDGE ROAD
# index: 13751
# item: Street       WILSON STREET
# Avg_Price       2.2575e+06
# Name: 13751, dtype: object
# item.Street only: WILSON STREET
# index: 13779
# item: Street       WINCHENDON ROAD
# Avg_Price           2.35e+06
# Name: 13779, dtype: object
# item.Street only: WINCHENDON ROAD
# index: 13816
# item: Street       WINGATE ROAD
# Avg_Price      2.2064e+06
# Name: 13816, dtype: object
# item.Street only: WINGATE ROAD

# %%
geolocator = Nominatim()
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:1: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   if __name__ == '__main__':

# %%
df_affordable['city_coord'] = df_affordable['Street'].apply(geolocator.geocode).apply(lambda x: (x.latitude, x.longitude))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /opt/conda/envs/Python36/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# /opt/conda/envs/Python36/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# /opt/conda/envs/Python36/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# /opt/conda/envs/Python36/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# /opt/conda/envs/Python36/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# /opt/conda/envs/Python36/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# /opt/conda/envs/Python36/lib/python3.6/http/client.py in connect(self)
#    1391
# -> 1392             super().connect()
#    1393
#
# /opt/conda/envs/Python36/lib/python3.6/http/client.py in connect(self)
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /opt/conda/envs/Python36/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     723     if err is not None:
# --> 724         raise err
#     725     else:
#
# /opt/conda/envs/Python36/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#
# OSError: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# /opt/conda/envs/Python36/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     525
# --> 526         response = self._open(req, data)
#     527
#
# /opt/conda/envs/Python36/lib/python3.6/urllib/request.py in _open(self, req, data)
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#
# /opt/conda/envs/Python36/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# /opt/conda/envs/Python36/lib/python3.6/urllib/request.py in https_open(self, req)
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#
# /opt/conda/envs/Python36/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#
# URLError: <urlopen error [Errno 101] Network is unreachable>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderUnavailable                       Traceback (most recent call last)
# <ipython-input-65-0f5362039c03> in <module>
# ----> 1 df_affordable['city_coord'] = df_affordable['Street'].apply(geolocator.geocode).apply(lambda x: (x.latitude, x.longitude))
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     385
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#     389
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     378                     raise GeocoderTimedOut('Service timed out')
#     379                 elif "unreachable" in message:
# --> 380                     raise GeocoderUnavailable('Service not available')
#     381             elif isinstance(error, SocketTimeout):
#     382                 raise GeocoderTimedOut('Service timed out')
#
# GeocoderUnavailable: Service not available

# %%
df_affordable
# Out:
#                           Street     Avg_Price
# 196                ALBION SQUARE  2.450000e+06
# 391                  ANHALT ROAD  2.435000e+06
# 406              ANSDELL TERRACE  2.250000e+06
# 422              APPLEGARTH ROAD  2.400000e+06
# 855              BARONSMEAD ROAD  2.375000e+06
# 981               BEAUCLERC ROAD  2.480000e+06
# 1102             BELVEDERE DRIVE  2.340000e+06
# 1215           BICKENHALL STREET  2.208500e+06
# 1253           BIRCHLANDS AVENUE  2.217000e+06
# 1553              BRAMPTON GROVE  2.456875e+06
# 1632           BRIARDALE GARDENS  2.397132e+06
# 1797                    BROOKWAY  2.400000e+06
# 1914                BURBAGE ROAD  2.445000e+06
# 1980                   BURY WALK  2.492500e+06
# 2068             CALLCOTT STREET  2.375000e+06
# 2129           CAMPDEN HILL ROAD  2.379653e+06
# 2136                CAMPION ROAD  2.461000e+06
# 2158               CANNING PLACE  2.425000e+06
# 2225               CARLISLE ROAD  2.200000e+06
# 2230             CARLTON GARDENS  2.483500e+06
# 2242               CARLYLE COURT  2.300000e+06
# 2405              CHALCOT SQUARE  2.286679e+06
# 2483                CHARLES LANE  2.414000e+06
# 2561            CHELSEA CRESCENT  2.495000e+06
# 2605         CHESTER CLOSE NORTH  2.450000e+06
# 2637                CHEYNE COURT  2.250000e+06
# 2640                  CHEYNE ROW  2.410000e+06
# 2685               CHISWICK MALL  2.287500e+06
# 2760                   CITY ROAD  2.468340e+06
# 2807            CLARENDON STREET  2.250000e+06
# 2899            CLONCURRY STREET  2.388333e+06
# 2943                COLBECK MEWS  2.367500e+06
# 2994            COLLEGE CRESCENT  2.440000e+06
# 3201       CORNWALL TERRACE MEWS  2.350000e+06
# 3254          COURT LANE GARDENS  2.360000e+06
# 3376              CRESCENT GROVE  2.298000e+06
# 3582               DALEBURY ROAD  2.400000e+06
# 3847               DEWHURST ROAD  2.425000e+06
# 3928                  DORIA ROAD  2.362500e+06
# 3979              DOWNSHIRE HILL  2.225000e+06
# 4034                DUCHESS WALK  2.477500e+06
# 4231       ECCLESTON SQUARE MEWS  2.335500e+06
# 4284               EGBERT STREET  2.265000e+06
# 4288               EGERTON PLACE  2.200000e+06
# 4373               ELM PARK ROAD  2.320425e+06
# 5011             FRANK DIXON WAY  2.212500e+06
# 5093                 FULTON MEWS  2.299000e+06
# 5236                 GERARD ROAD  2.258500e+06
# 5239                GERRARD ROAD  2.242500e+06
# 5284               GIRDLERS ROAD  2.441667e+06
# 5377         GLOUCESTER CRESCENT  2.350833e+06
# 5445                GORDON PLACE  2.477000e+06
# 5481              GRAFTON SQUARE  2.270000e+06
# 5488              GRAHAM TERRACE  2.325000e+06
# 5946                HARMAN DRIVE  2.262500e+06
# 5970               HARRIS STREET  2.471769e+06
# 6032             HAVANNAH STREET  2.217309e+06
# 6104              HAZLEWELL ROAD  2.500000e+06
# 6220               HEREFORD MEWS  2.310000e+06
# 6240            HERONDALE AVENUE  2.475000e+06
# 6337        HIGHGATE HIGH STREET  2.211000e+06
# 6352               HIGHWOOD HILL  2.252500e+06
# 6388              HILLGATE PLACE  2.200000e+06
# 6499           HOLLYCROFT AVENUE  2.361375e+06
# 6503              HOLLYWOOD MEWS  2.350000e+06
# 6548              HONEYWELL ROAD  2.278333e+06
# 6603              HORTENSIA ROAD  2.275917e+06
# 6632               HOXTON SQUARE  2.234286e+06
# 6658                 HUNTER ROAD  2.300000e+06
# 6817               JACKSONS LANE  2.362500e+06
# 6877                 JOHN STREET  2.235000e+06
# 7181            KINNERTON STREET  2.485600e+06
# 7215         KNARESBOROUGH PLACE  2.325000e+06
# 7235                 KNOX STREET  2.250000e+06
# 7255              LADBROKE GROVE  2.483300e+06
# 7324              LANCASTER MEWS  2.312500e+06
# 7394              LANSDOWNE ROAD  2.429871e+06
# 11773      ST MARGARETS CRESCENT  2.216500e+06
# 11809           ST OSWALDS PLACE  2.250000e+06
# 11829           ST PETERS SQUARE  2.468730e+06
# 11866           STAFFORD TERRACE  2.355000e+06
# 12205           SUTHERLAND PLACE  2.456000e+06
# 12267              SYDNEY STREET  2.240833e+06
# 12409                THAMES BANK  2.400000e+06
# 12471                THE HEXAGON  2.335000e+06
# 12750            TREDEGAR SQUARE  2.436666e+06
# 12812             TRINITY STREET  2.317500e+06
# 12962       UPPER HAMPSTEAD WALK  2.500000e+06
# 13224            WALPOLE GARDENS  2.303500e+06
# 13226             WALPOLE STREET  2.242500e+06
# 13300             WARWICK SQUARE  2.432273e+06
# 13398                WELBECK WAY  2.267000e+06
# 13410          WELLESLEY TERRACE  2.410000e+06
# 13421          WELLINGTON STREET  2.293155e+06
# 13553         WESTMORELAND PLACE  2.300000e+06
# 13660           WHITFIELD STREET  2.451000e+06
# 13705             WILFRED STREET  2.410538e+06
# 13731         WILLOW BRIDGE ROAD  2.425000e+06
# 13751              WILSON STREET  2.257500e+06
# 13779            WINCHENDON ROAD  2.350000e+06
# 13816               WINGATE ROAD  2.206400e+06

# %%
df_affordable[['Latitude', 'Longitude']] = df_affordable['city_coord'].apply(pd.Series)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'city_coord'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-0fea049c2a97> in <module>
# ----> 1 df_affordable[['Latitude', 'Longitude']] = df_affordable['city_coord'].apply(pd.Series)
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'city_coord'

# %%
df_affordable
# Out:
#                           Street     Avg_Price
# 196                ALBION SQUARE  2.450000e+06
# 391                  ANHALT ROAD  2.435000e+06
# 406              ANSDELL TERRACE  2.250000e+06
# 422              APPLEGARTH ROAD  2.400000e+06
# 855              BARONSMEAD ROAD  2.375000e+06
# 981               BEAUCLERC ROAD  2.480000e+06
# 1102             BELVEDERE DRIVE  2.340000e+06
# 1215           BICKENHALL STREET  2.208500e+06
# 1253           BIRCHLANDS AVENUE  2.217000e+06
# 1553              BRAMPTON GROVE  2.456875e+06
# 1632           BRIARDALE GARDENS  2.397132e+06
# 1797                    BROOKWAY  2.400000e+06
# 1914                BURBAGE ROAD  2.445000e+06
# 1980                   BURY WALK  2.492500e+06
# 2068             CALLCOTT STREET  2.375000e+06
# 2129           CAMPDEN HILL ROAD  2.379653e+06
# 2136                CAMPION ROAD  2.461000e+06
# 2158               CANNING PLACE  2.425000e+06
# 2225               CARLISLE ROAD  2.200000e+06
# 2230             CARLTON GARDENS  2.483500e+06
# 2242               CARLYLE COURT  2.300000e+06
# 2405              CHALCOT SQUARE  2.286679e+06
# 2483                CHARLES LANE  2.414000e+06
# 2561            CHELSEA CRESCENT  2.495000e+06
# 2605         CHESTER CLOSE NORTH  2.450000e+06
# 2637                CHEYNE COURT  2.250000e+06
# 2640                  CHEYNE ROW  2.410000e+06
# 2685               CHISWICK MALL  2.287500e+06
# 2760                   CITY ROAD  2.468340e+06
# 2807            CLARENDON STREET  2.250000e+06
# 2899            CLONCURRY STREET  2.388333e+06
# 2943                COLBECK MEWS  2.367500e+06
# 2994            COLLEGE CRESCENT  2.440000e+06
# 3201       CORNWALL TERRACE MEWS  2.350000e+06
# 3254          COURT LANE GARDENS  2.360000e+06
# 3376              CRESCENT GROVE  2.298000e+06
# 3582               DALEBURY ROAD  2.400000e+06
# 3847               DEWHURST ROAD  2.425000e+06
# 3928                  DORIA ROAD  2.362500e+06
# 3979              DOWNSHIRE HILL  2.225000e+06
# 4034                DUCHESS WALK  2.477500e+06
# 4231       ECCLESTON SQUARE MEWS  2.335500e+06
# 4284               EGBERT STREET  2.265000e+06
# 4288               EGERTON PLACE  2.200000e+06
# 4373               ELM PARK ROAD  2.320425e+06
# 5011             FRANK DIXON WAY  2.212500e+06
# 5093                 FULTON MEWS  2.299000e+06
# 5236                 GERARD ROAD  2.258500e+06
# 5239                GERRARD ROAD  2.242500e+06
# 5284               GIRDLERS ROAD  2.441667e+06
# 5377         GLOUCESTER CRESCENT  2.350833e+06
# 5445                GORDON PLACE  2.477000e+06
# 5481              GRAFTON SQUARE  2.270000e+06
# 5488              GRAHAM TERRACE  2.325000e+06
# 5946                HARMAN DRIVE  2.262500e+06
# 5970               HARRIS STREET  2.471769e+06
# 6032             HAVANNAH STREET  2.217309e+06
# 6104              HAZLEWELL ROAD  2.500000e+06
# 6220               HEREFORD MEWS  2.310000e+06
# 6240            HERONDALE AVENUE  2.475000e+06
# 6337        HIGHGATE HIGH STREET  2.211000e+06
# 6352               HIGHWOOD HILL  2.252500e+06
# 6388              HILLGATE PLACE  2.200000e+06
# 6499           HOLLYCROFT AVENUE  2.361375e+06
# 6503              HOLLYWOOD MEWS  2.350000e+06
# 6548              HONEYWELL ROAD  2.278333e+06
# 6603              HORTENSIA ROAD  2.275917e+06
# 6632               HOXTON SQUARE  2.234286e+06
# 6658                 HUNTER ROAD  2.300000e+06
# 6817               JACKSONS LANE  2.362500e+06
# 6877                 JOHN STREET  2.235000e+06
# 7181            KINNERTON STREET  2.485600e+06
# 7215         KNARESBOROUGH PLACE  2.325000e+06
# 7235                 KNOX STREET  2.250000e+06
# 7255              LADBROKE GROVE  2.483300e+06
# 7324              LANCASTER MEWS  2.312500e+06
# 7394              LANSDOWNE ROAD  2.429871e+06
# 7422   LATIMER INDUSTRIAL ESTATE  2.400000e+06
# 7475                LAXTON PLACE  2.500000e+06
# 7677              LINCOLN AVENUE  2.203500e+06
# 7705              LINGFIELD ROAD  2.248750e+06
# 7734               LISSON STREET  2.462500e+06
# 7768             LIVERPOOL GROVE  2.288000e+06
# 7860              LONGWOOD DRIVE  2.375000e+06
# 7866             LONSDALE SQUARE  2.357500e+06
# 8404                   MAZE HILL  2.250000e+06
# 8539           MIDDLESEX PASSAGE  2.280000e+06
# 8702           MONTPELIER AVENUE  2.500000e+06
# 8712             MONTPELIER WALK  2.320000e+06
# 8860                 MULTON ROAD  2.300000e+06
# 13398                WELBECK WAY  2.267000e+06
# 13410          WELLESLEY TERRACE  2.410000e+06
# 13421          WELLINGTON STREET  2.293155e+06
# 13553         WESTMORELAND PLACE  2.300000e+06
# 13660           WHITFIELD STREET  2.451000e+06
# 13705             WILFRED STREET  2.410538e+06
# 13731         WILLOW BRIDGE ROAD  2.425000e+06
# 13751              WILSON STREET  2.257500e+06
# 13779            WINCHENDON ROAD  2.350000e+06
# 13816               WINGATE ROAD  2.206400e+06

# %%
df = df_affordable.drop(columns=['city_coord'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-ef4d0e1ad4db> in <module>
#       1
# ----> 2 df = df_affordable.drop(columns=['city_coord'])
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4962             if errors != 'ignore':
#    4963                 raise KeyError(
# -> 4964                     '{} not found in axis'.format(labels[mask]))
#    4965             indexer = indexer[~mask]
#    4966         return self.delete(indexer)
#
# KeyError: "['city_coord'] not found in axis"

# %%
df()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-5cbf87521eaa> in <module>
# ----> 1 df()
#
# NameError: name 'df' is not defined

# %%
address = 'London, UK'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of London City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of London City are 51.5073219, -0.1276474.
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   app.launch_new_instance()

# %%
map_london = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, price, street in zip(df['Latitude'], df['Longitude'], df['Avg_Price'], df['Street']):
    label = '{}, {}'.format(street, price)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_london)  
    
map_london
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-48d212077cdb> in <module>
#       2
#       3 # add markers to map
# ----> 4 for lat, lng, price, street in zip(df['Latitude'], df['Longitude'], df['Avg_Price'], df['Street']):
#       5     label = '{}, {}'.format(street, price)
#       6     label = folium.Popup(label, parse_html=True)
#
# NameError: name 'df' is not defined

# %%
#Define Foursquare Credentials and Version

CLIENT_ID = 'KI3TR0QO4JOKMFELOMF3WSOOI3HFNBF5YLW354MYWBKDHEX3' # Foursquare ID
CLIENT_SECRET = 'QF4ZBLJRBV4BQX52DVWUPEHJ14A2UJABPCZARZQZYTKIISUD' # Foursquare Secret
VERSION = '20181206' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: KI3TR0QO4JOKMFELOMF3WSOOI3HFNBF5YLW354MYWBKDHEX3
# CLIENT_SECRET:QF4ZBLJRBV4BQX52DVWUPEHJ14A2UJABPCZARZQZYTKIISUD

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500, LIMIT=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Street', 
                  'Street Latitude', 
                  'Street Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# Run the above function on each location and create a new dataframe called location_venues and display it.
location_venues = getNearbyVenues(names=df['Street'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-4605bed49bf6> in <module>
#       1
#       2 # Run the above function on each location and create a new dataframe called location_venues and display it.
# ----> 3 location_venues = getNearbyVenues(names=df['Street'],
#       4                                    latitudes=df['Latitude'],
#       5                                    longitudes=df['Longitude']
#
# NameError: name 'df' is not defined

# %%
location_venues
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-8b0cd217f373> in <module>
# ----> 1 location_venues
#
# NameError: name 'location_venues' is not defined
